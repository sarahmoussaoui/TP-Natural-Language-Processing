# %% [markdown]
# # Libraries

# %%
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\moous\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moous\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # loading and preprocessing data

# %%
import os
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    return tokens

data = []
labels = []

base_path = "TP/All-in-many/"
label_path = "TP/All-in-many_classification/"

for filename in os.listdir(base_path):
    article_file = os.path.join(base_path, filename)
    label_file = os.path.join(label_path, filename)
    
    if os.path.isfile(article_file) and os.path.isfile(label_file):
        # --- Try to read with UTF-8, fallback to Latin-1 ---
        try:
            with open(article_file, encoding='utf-8') as f:
                text = f.read()
        except UnicodeDecodeError:
            with open(article_file, encoding='latin-1') as f:
                text = f.read()
        
        try:
            with open(label_file, encoding='utf-8') as f:
                label = f.read().strip()
        except UnicodeDecodeError:
            with open(label_file, encoding='latin-1') as f:
                label = f.read().strip()
        
        data.append(preprocess_text(text))
        labels.append(label)
    else:
        print(f"⚠️ Missing match for {filename}")

print(f"\n✅ Loaded {len(data)} documents")
print("Classes found:", set(labels))
# Out:
# ✅ Loaded 118 documents
# Classes found: {'2', '4', '\x00\x00\x00\x01Bud1\x00\x008\x00\x00\x00\x08\x00\x00\x008\x00\x00\x00\x10\x0c\x00\x00\x01\x08\x00\x00 \x0c\x00\x000\x0b\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x08\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x01\x00\x00\x00u\x00\x00\x00\x04\x00\x00\x10\x00\x00t\x00i\x00c\x00l\x00e\x00_A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x004\x005\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x00²\x00\x00"¾ÿÿÿÿÿÿ\x00\x00\x00\x00\x00\x05\x00\x00\x00\x14\x00A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x007\x001\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x01\x92\x00\x00->ÿÿÿÿÿÿ\x00\x00\x00t\x00i\x00c\x00l\x00e\x00_\x004\x008\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x02\x02\x00\x00$\x0eÿÿÿÿÿÿ\x00\x00\x00\x00\x00\x14\x00A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x004\x009\x00_\x00V\x00o\x00l\x ...

# %%
print(f"\n✅ Loaded {len(data)} documents")
print("Raw numeric classes found:", set(labels))

# Convert to human-readable labels
num_to_label = {
    "1": "Metaheuristics",
    "2": "Machine & Deep Learning",
    "3": "Combination of Metaheuristics & Machine/Deep Learning",
    "4": "Others"
}
text_labels = [num_to_label.get(lbl, "Unknown") for lbl in labels]
print("Mapped text labels:", set(text_labels))
# Out:
# ✅ Loaded 118 documents
# Raw numeric classes found: {'2', '4', '\x00\x00\x00\x01Bud1\x00\x008\x00\x00\x00\x08\x00\x00\x008\x00\x00\x00\x10\x0c\x00\x00\x01\x08\x00\x00 \x0c\x00\x000\x0b\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x08\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x01\x00\x00\x00u\x00\x00\x00\x04\x00\x00\x10\x00\x00t\x00i\x00c\x00l\x00e\x00_A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x004\x005\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x00²\x00\x00"¾ÿÿÿÿÿÿ\x00\x00\x00\x00\x00\x05\x00\x00\x00\x14\x00A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x007\x001\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x01\x92\x00\x00->ÿÿÿÿÿÿ\x00\x00\x00t\x00i\x00c\x00l\x00e\x00_\x004\x008\x00_\x00V\x00o\x00l\x00u\x00m\x00e\x00_\x001\x008Ilocblob\x00\x00\x00\x10\x00\x00\x02\x02\x00\x00$\x0eÿÿÿÿÿÿ\x00\x00\x00\x00\x00\x14\x00A\x00r\x00t\x00i\x00c\x00l\x00e\x00_\x004\x009\x00_\x00V\x00o\x00l\x ...
# Mapped text labels: {'Machine & Deep Learning', 'Combination of Metaheuristics & Machine/Deep Learning', 'Others', 'Unknown', 'Metaheuristics'}

# %%
base_path = "TP/All-in-many/"
label_path = "TP/All-in-many_classification/"
for filename in os.listdir(base_path):
    article_file = os.path.join(base_path, filename)
    label_file = os.path.join(label_path, filename)
    print("label file",label_file)

    if not os.path.isfile(label_file):
        print("Label file not found:", label_file)
# Out:
# label file TP/All-in-many_classification/.DS_Store
# label file TP/All-in-many_classification/Article_100_Volume_18
# label file TP/All-in-many_classification/Article_101_Volume_18
# label file TP/All-in-many_classification/Article_102_Volume_18
# label file TP/All-in-many_classification/Article_103_Volume_18
# label file TP/All-in-many_classification/Article_104_Volume_18
# label file TP/All-in-many_classification/Article_105_Volume_18
# label file TP/All-in-many_classification/Article_106_Volume_18
# label file TP/All-in-many_classification/Article_107_Volume_18
# label file TP/All-in-many_classification/Article_108_Volume_18
# label file TP/All-in-many_classification/Article_109_Volume_18
# label file TP/All-in-many_classification/Article_10_Volume_18
# label file TP/All-in-many_classification/Article_110_Volume_18
# label file TP/All-in-many_classification/Article_111_Volume_18
# label file TP/All-in-many_classification/Article_112_Volume_18
# label file TP/All-in-many_classification/Article_113_Volume_18
# label file TP/All-in-many_classification/Article_114_Volume_18
# label file TP/All-in-many_classification/Article_115_Volume_18
# label file TP/All-in-many_classification/Article_116_Volume_18
# label file TP/All-in-many_classification/Article_117_Volume_18
# label file TP/All-in-many_classification/Article_11_Volume_18
# label file TP/All-in-many_classification/Article_12_Volume_18
# label file TP/All-in-many_classification/Article_13_Volume_18
# label file TP/All-in-many_classification/Article_14_Volume_18
# label file TP/All-in-many_classification/Article_15_Volume_18
# label file TP/All-in-many_classification/Article_16_Volume_18
# label file TP/All-in-many_classification/Article_17_Volume_18
# label file TP/All-in-many_classification/Article_18_Volume_18
# label file TP/All-in-many_classification/Article_19_Volume_18
# label file TP/All-in-many_classification/Article_1_Volume_18
# label file TP/All-in-many_classification/Article_20_Volume_18
# label file TP/All-in-many_classification/Article_21_Volume_18
# label file TP/All-in-many_classification/Article_22_Volume_18
# label file TP/All-in-many_classification/Article_23_Volume_18
# label file TP/All-in-many_classification/Article_24_Volume_18
# label file TP/All-in-many_classification/Article_25_Volume_18
# label file TP/All-in-many_classification/Article_26_Volume_18
# label file TP/All-in-many_classification/Article_27_Volume_18
# label file TP/All-in-many_classification/Article_28_Volume_18
# label file TP/All-in-many_classification/Article_29_Volume_18
# label file TP/All-in-many_classification/Article_2_Volume_18
# label file TP/All-in-many_classification/Article_30_Volume_18
# label file TP/All-in-many_classification/Article_31_Volume_18
# label file TP/All-in-many_classification/Article_32_Volume_18
# label file TP/All-in-many_classification/Article_33_Volume_18
# label file TP/All-in-many_classification/Article_34_Volume_18
# label file TP/All-in-many_classification/Article_35_Volume_18
# label file TP/All-in-many_classification/Article_36_Volume_18
# label file TP/All-in-many_classification/Article_37_Volume_18
# label file TP/All-in-many_classification/Article_38_Volume_18
# label file TP/All-in-many_classification/Article_39_Volume_18
# label file TP/All-in-many_classification/Article_3_Volume_18
# label file TP/All-in-many_classification/Article_40_Volume_18
# label file TP/All-in-many_classification/Article_41_Volume_18
# label file TP/All-in-many_classification/Article_42_Volume_18
# label file TP/All-in-many_classification/Article_43_Volume_18
# label file TP/All-in-many_classification/Article_44_Volume_18
# label file TP/All-in-many_classification/Article_45_Volume_18
# label file TP/All-in-many_classification/Article_46_Volume_18
# label file TP/All-in-many_classification/Article_47_Volume_18
# label file TP/All-in-many_classification/Article_48_Volume_18
# label file TP/All-in-many_classification/Article_49_Volume_18
# label file TP/All-in-many_classification/Article_4_Volume_18
# label file TP/All-in-many_classification/Article_50_Volume_18
# label file TP/All-in-many_classification/Article_51_Volume_18
# label file TP/All-in-many_classification/Article_52_Volume_18
# label file TP/All-in-many_classification/Article_53_Volume_18
# label file TP/All-in-many_classification/Article_54_Volume_18
# label file TP/All-in-many_classification/Article_55_Volume_18
# label file TP/All-in-many_classification/Article_56_Volume_18
# label file TP/All-in-many_classification/Article_57_Volume_18
# label file TP/All-in-many_classification/Article_58_Volume_18
# label file TP/All-in-many_classification/Article_59_Volume_18
# label file TP/All-in-many_classification/Article_5_Volume_18
# label file TP/All-in-many_classification/Article_60_Volume_18
# label file TP/All-in-many_classification/Article_61_Volume_18
# label file TP/All-in-many_classification/Article_62_Volume_18
# label file TP/All-in-many_classification/Article_63_Volume_18
# label file TP/All-in-many_classification/Article_64_Volume_18
# label file TP/All-in-many_classification/Article_65_Volume_18
# label file TP/All-in-many_classification/Article_66_Volume_18
# label file TP/All-in-many_classification/Article_67_Volume_18
# label file TP/All-in-many_classification/Article_68_Volume_18
# label file TP/All-in-many_classification/Article_69_Volume_18
# label file TP/All-in-many_classification/Article_6_Volume_18
# label file TP/All-in-many_classification/Article_70_Volume_18
# label file TP/All-in-many_classification/Article_71_Volume_18
# label file TP/All-in-many_classification/Article_72_Volume_18
# label file TP/All-in-many_classification/Article_73_Volume_18
# label file TP/All-in-many_classification/Article_74_Volume_18
# label file TP/All-in-many_classification/Article_75_Volume_18
# label file TP/All-in-many_classification/Article_76_Volume_18
# label file TP/All-in-many_classification/Article_77_Volume_18
# label file TP/All-in-many_classification/Article_78_Volume_18
# label file TP/All-in-many_classification/Article_79_Volume_18
# label file TP/All-in-many_classification/Article_7_Volume_18
# label file TP/All-in-many_classification/Article_80_Volume_18
# label file TP/All-in-many_classification/Article_81_Volume_18
# label file TP/All-in-many_classification/Article_82_Volume_18
# label file TP/All-in-many_classification/Article_83_Volume_18
# label file TP/All-in-many_classification/Article_84_Volume_18
# label file TP/All-in-many_classification/Article_85_Volume_18
# label file TP/All-in-many_classification/Article_86_Volume_18
# label file TP/All-in-many_classification/Article_87_Volume_18
# label file TP/All-in-many_classification/Article_88_Volume_18
# label file TP/All-in-many_classification/Article_89_Volume_18
# label file TP/All-in-many_classification/Article_8_Volume_18
# label file TP/All-in-many_classification/Article_90_Volume_18
# label file TP/All-in-many_classification/Article_91_Volume_18
# label file TP/All-in-many_classification/Article_92_Volume_18
# label file TP/All-in-many_classification/Article_93_Volume_18
# label file TP/All-in-many_classification/Article_94_Volume_18
# label file TP/All-in-many_classification/Article_95_Volume_18
# label file TP/All-in-many_classification/Article_96_Volume_18
# label file TP/All-in-many_classification/Article_97_Volume_18
# label file TP/All-in-many_classification/Article_98_Volume_18
# label file TP/All-in-many_classification/Article_99_Volume_18
# label file TP/All-in-many_classification/Article_9_Volume_18

# %%
# delete first item of data
del data[0]
del labels[0]

# %% [markdown]
# # Probabilities calculations

# %% [markdown]
# for each document we need to compute the probability of each class

# %% [markdown]
# The most probable class 𝒄" for a given document 𝒅 is computed by selecting the class with the highest product of two probabilities:
#
# o The prior probability of the class 𝑷(𝒄)
#
# o The probability of the document given the class 𝑷(𝒅|𝒄)
#
#               𝒄 = 𝐚𝐫𝐠 𝐦𝐚𝐱 𝑷(𝒄) 𝑷(𝒅|𝒄)
#
# o The document 𝒅 can be represented as a set of words:
#               𝒄 = 𝐚𝐫𝐠 𝐦𝐚𝐱 𝑷(𝒄) 𝑷(𝒘𝟏, 𝒘𝟐, 𝒘𝟑 … , 𝒘𝒏|𝒄)
#
# o The probability 𝑷(𝒄) represents the proportion of documents in the training set that belong to class c
#
#               𝑷(𝒄) = 𝑵𝒄 / 𝑵
#
#
# 𝑵𝒄 is the number of documents in the training set belonging to class 𝒄.
#
# 𝑵 is the total number of documents in the training set.
#
# o The probability 𝑷(𝒘𝟏, 𝒘𝟐, 𝒘𝟑 … , 𝒘𝒏|𝒄) is computed as the product of the individual probabilities:
#
#             𝑷(𝒘𝟏, 𝒘𝟐, 𝒘𝟑 … , 𝒘𝒏|𝒄) = product 𝑷(𝒘𝒊|𝒄) i ranging from 1 to n
#
# Where:
#
# The probability 𝑷(𝒘𝒊|𝒄) corresponds to the relative frequency of the word 𝒘𝒊 among all words in documents belonging to class 𝒄:
#
#               𝑷(𝒘𝒊|𝒄) = (𝐜𝐨𝐮𝐧𝐭(𝒘𝒊, 𝒄) + 𝟏) / ∑ 𝐜𝐨𝐮𝐧𝐭(𝒘, 𝒄) + 𝑽
#
# Where:
# 𝑽 represents the vocabulary of the training set.

# %% [markdown]
# vocabulary

# %%
from collections import Counter

vocab = set()
for doc in data:
    vocab.update(doc)
V = len(vocab)

# %% [markdown]
# P(c)

# %%
from collections import defaultdict
import math

class_docs = defaultdict(list)
for tokens, label in zip(data, labels):
    class_docs[label].append(tokens)

N = len(data)
P_c = {c: len(docs)/N for c, docs in class_docs.items()}

# %% [markdown]
# p(w\c)

# %%
word_counts = {}
total_words = {}

for c, docs in class_docs.items():
    word_counts[c] = Counter([w for doc in docs for w in doc])
    total_words[c] = sum(word_counts[c].values())

def P_w_given_c(word, c):
    return (word_counts[c][word] + 1) / (total_words[c] + V)

# %% [markdown]
# classify a new article

# %%
def classify(tokens):
    scores = {}
    for c in P_c:
        # log probabilities to avoid underflow
        log_prob = math.log(P_c[c])
        for w in tokens:
            if w in vocab:
                log_prob += math.log(P_w_given_c(w, c))
        scores[c] = log_prob
    return max(scores, key=scores.get), scores

# %% [markdown]
# ## Interface

# %%
# Map labels to class names
num_to_label = {
    "1": "Metaheuristics",
    "2": "Machine & Deep Learning",
    "3": "Combination of Metaheuristics & Machine/Deep Learning",
    "4": "Others"
}


labels_summary = []
for i, lbl_num in enumerate(labels, start=1):  # article numbers start from 1
    labels_summary.append({
        "article_num": i,
        "class_num": lbl_num,
        "label": num_to_label.get(lbl_num, "Unknown")  # map number to text
    })

# %%
import tkinter as tk
from tkinter import ttk
from collections import Counter


# Map numeric labels to text labels
num_to_label = {
    "1": "Metaheuristics",
    "2": "Machine & Deep Learning",
    "3": "Combination of Metaheuristics & Machine/Deep Learning",
    "4": "Others"
}

# -------------------------
# Prepare per-article summary
labels_summary = []
for i, lbl_num in enumerate(labels, start=1):
    labels_summary.append({
        "article_num": i,
        "class_num": lbl_num,
        "label": num_to_label.get(lbl_num, "Unknown")
    })

# -------------------------
# Probabilities
label_counts = Counter(labels)
total_docs = len(labels)
class_probs = {lbl: label_counts[lbl]/total_docs for lbl in label_counts}

# Conditional probabilities
vocab = set(token for doc in data for token in doc)
token_counts = {lbl: Counter() for lbl in label_counts}
total_tokens_per_class = {lbl: 0 for lbl in label_counts}

for doc, lbl in zip(data, labels):
    token_counts[lbl].update(doc)
    total_tokens_per_class[lbl] += len(doc)

V = len(vocab)
conditional_probs = []
for token in vocab:
    row = {"token": token}
    for lbl in label_counts:
        row[lbl] = (token_counts[lbl][token] + 1) / (total_tokens_per_class[lbl] + V)
    conditional_probs.append(row)

# -------------------------
# Tkinter UI
root = tk.Tk()
root.title("Naive Bayes Visualization & Training")
root.geometry("1000x700")
root.configure(bg="#f5f5f5")

button_frame = tk.Frame(root, bg="#f5f5f5")
button_frame.pack(pady=20)
output_frame = tk.Frame(root, bg="#f5f5f5")
output_frame.pack(pady=10, fill="both", expand=True)

def clear_output():
    for widget in output_frame.winfo_children():
        widget.destroy()

def show_visualization():
    clear_output()
    ttk.Label(output_frame, text="📊 Data Summary", font=("Arial", 14, "bold")).pack(pady=5)
    
    tree = ttk.Treeview(output_frame, columns=("article_num", "class_num", "label"), show="headings", height=15)
    tree.pack(padx=10, pady=10, fill="both", expand=True)

    tree.heading("article_num", text="Article Number")
    tree.heading("class_num", text="Class Number")
    tree.heading("label", text="Label")

    for row in labels_summary:
        tree.insert("", "end", values=(row["article_num"], row["class_num"], row["label"]))

def show_training():
    clear_output()

    # --- Table 1: Class probabilities ---
    ttk.Label(output_frame, text="🧠 Estimated Class Probabilities", font=("Arial", 14, "bold")).pack(pady=5)
    
    cols = [f'{lbl} ({num_to_label[lbl]})' for lbl in sorted(class_probs.keys())]
    tree1 = ttk.Treeview(output_frame, columns=cols, show="headings", height=3)
    tree1.pack(padx=10, pady=10, fill="x")

    for col in cols:
        tree1.heading(col, text=col)

    tree1.insert("", "end", values=[class_probs[lbl] for lbl in sorted(class_probs.keys())])

    # --- Table 2: Conditional probabilities ---
    ttk.Label(output_frame, text="📈 Conditional Probabilities P(w|c)", font=("Arial", 14, "bold")).pack(pady=5)
    
    tree2 = ttk.Treeview(output_frame, columns=["Token"] + sorted(class_probs.keys()), show="headings", height=10)
    tree2.pack(padx=10, pady=10, fill="both", expand=True)

    tree2.heading("Token", text="Token")
    for lbl in sorted(class_probs.keys()):
        tree2.heading(lbl, text=f"{lbl} ({num_to_label[lbl]})")

    for row in conditional_probs:
        tree2.insert("", "end", values=[row["token"]] + [row[lbl] for lbl in sorted(class_probs.keys())])

# -------------------------
# Buttons
btn_visualize = ttk.Button(button_frame, text="Visualization", command=show_visualization)
btn_visualize.grid(row=0, column=0, padx=20)
btn_train = ttk.Button(button_frame, text="Training", command=show_training)
btn_train.grid(row=0, column=1, padx=20)

root.mainloop()
